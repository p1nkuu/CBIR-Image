# %%
import uni_functions as uni
import numpy as np
#Token : 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
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
list_filenames = uni.img_folder_to_str('/Users/genesishang/bttai_novartis/pubmed_set/images', '.png')

# %%
img_path = '/Users/genesishang/bttai_novartis/pubmed_set/images/'
caption_file = '/Users/genesishang/bttai_novartis/pubmed_set/captions.json'
file_types = ['.jpg', '.png']
np_filename = 'pubmed_embeddings'

# %%
uni.generate_embeddings_w_UID(img_path, caption_file, file_types, np_filename, subset=False)

# %%
data = np.load(np_filename+'.npy') #Outputs 3D embeddings so..
new_data = data.reshape(data.shape[0]*data.shape[1], data.shape[2])
d = new_data.shape[-1]

# %%
list_matches = uni.img_folder_to_str('/Users/genesishang/bttai_novartis/matches', ['.png','.jpg'])

# %%
# index.add() #Add eval embeddings
data_matches = np.load('uni_embeddings_matches.npy') #Outputs 3D embeddings so..
new_data_matches = data_matches.reshape(data_matches.shape[0]*data_matches.shape[1], data_matches.shape[2])
# d = new_data.shape[-1]

# %%
index_list = list_filenames+list_matches #Check Index Size
len(index_list)
# Out:
# 3357

# %%
index = uni.create_index(d, [new_data, new_data_matches])

# %%
index.is_trained
# Out:
# True

# %%
index.ntotal
# Out:
# 3357

# %%
query_img = uni.query_image_embedding('/Users/genesishang/bttai_novartis/pubmed_set/images/8a662f40-e8b5-47d3-9ce5-95c1823e3789.jpg')

# %%
distance_index = uni.perform_knn(k=20, index=index, query_img=query_img)

# %%
# uni.KNN_|filenames(I, filenames=)
distance_index
# Out:
# ([0.0,
#   980.369384765625,
#   1115.97705078125,
#   1157.463623046875,
#   1172.35498046875,
#   1185.5126953125,
#   1195.430908203125,
#   1230.3095703125,
#   1236.4647216796875,
#   1241.18505859375,
#   1268.1295166015625,
#   1281.21630859375,
#   1286.8585205078125,
#   1299.011962890625,
#   1301.2010498046875,
#   1318.575927734375,
#   1320.8221435546875,
#   1334.2294921875,
#   1336.1043701171875,
#   1361.592529296875],
#  [387,
#   3316,
#   254,
#   3311,
#   253,
#   3315,
#   229,
#   1314,
#   1633,
#   298,
#   2039,
#   1975,
#   250,
#   1943,
#   750,
#   2622,
#   2877,
#   412,
#   257,
#   777])

# %%
print("Query vector:", query_img)
print("Ranked Indices of Nearest Neighbors:", distance_index[1])
print("Ranked Distances of Nearest Neighbors:", distance_index[0])

# Getting actual ranks - Since distances are sorted, the order represents ranks
ranked_results = list(zip(distance_index[0], distance_index[1]))
print("Ranked Results (Index, Distance):", ranked_results)
# Out:
# Query vector: tensor([[ 0.0543,  3.0071,  1.9024,  ..., -1.5313,  2.4779,  1.4742]])
# Ranked Indices of Nearest Neighbors: [387, 3316, 254, 3311, 253, 3315, 229, 1314, 1633, 298, 2039, 1975, 250, 1943, 750, 2622, 2877, 412, 257, 777]
# Ranked Distances of Nearest Neighbors: [0.0, 980.369384765625, 1115.97705078125, 1157.463623046875, 1172.35498046875, 1185.5126953125, 1195.430908203125, 1230.3095703125, 1236.4647216796875, 1241.18505859375, 1268.1295166015625, 1281.21630859375, 1286.8585205078125, 1299.011962890625, 1301.2010498046875, 1318.575927734375, 1320.8221435546875, 1334.2294921875, 1336.1043701171875, 1361.592529296875]
# Ranked Results (Index, Distance): [(0.0, 387), (980.369384765625, 3316), (1115.97705078125, 254), (1157.463623046875, 3311), (1172.35498046875, 253), (1185.5126953125, 3315), (1195.430908203125, 229), (1230.3095703125, 1314), (1236.4647216796875, 1633), (1241.18505859375, 298), (1268.1295166015625, 2039), (1281.21630859375, 1975), (1286.8585205078125, 250), (1299.011962890625, 1943), (1301.2010498046875, 750), (1318.575927734375, 2622), (1320.8221435546875, 2877), (1334.2294921875, 412), (1336.1043701171875, 257), (1361.592529296875, 777)]

# %%
uni.KNN_filenames(distance_index[1], filenames=index_list)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 uni.KNN_filenames(distance_index[1], filenames=index_list)
#
# File ~/bttai_novartis/uni_functions.py:220, in KNN_filenames(I, filenames)
#     218 results = []
#     219 for i in I:
# --> 220     results.append(filenames[I[i]])
#     221 return results
#
# IndexError: list index out of range
