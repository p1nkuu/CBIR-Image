# %%
import uni_functions as uni
#Token : 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

# %%
list_filenames = uni.img_folder_to_str('/Users/genesishang/books_set/images/', '.png')

# %%
subset = uni.shrink_dataset_random(list_filenames, sample_size=50)
len(subset)
# Out:
# 50

# %%
uni.generate_embeddings_w_UID('/Users/genesishang/books_set/captions.json', subset=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 uni.generate_embeddings_w_UID('/Users/genesishang/books_set/captions.json', subset=True)
#
# File ~/bttai_novartis/uni_functions.py:52, in generate_embeddings_w_UID(caption_file, model, subset)
#      50 while i <= int(sample_size):
#      51     for item in data:
# ---> 52         img_str = item.uuid #Image filename as String
#      53         uid = item['uid']
#      55         image = convert_to_RGB(img_str)
#
# AttributeError: 'str' object has no attribute 'uuid'
